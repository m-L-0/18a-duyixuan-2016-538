# %%
import numpy as np
import tensorflow as tf

# %%
(train_data, train_label), (test_data, test_label) =\
    tf.keras.datasets.boston_housing.load_data()

# %%
train_data.shape
# Out:
# (404, 13)

# %%
train_label.shape
# Out:
# (404,)

# %%
with tf.Graph().as_default() as g:
    inputs = tf.placeholder(shape=[None, 13], dtype=tf.float32)
    labels = tf.placeholder(shape=[None], dtype=tf.float32)
    
    h1 = tf.keras.layers.Dense(64, activation=tf.nn.relu)(inputs)
    h2 = tf.keras.layers.Dense(16, activation=tf.nn.relu)(h1)
    output = tf.keras.layers.Dense(1, activation=None)(h2)
    
    loss = tf.reduce_mean(
        tf.keras.losses.mean_squared_error(labels, output))
    
    optim = tf.train.GradientDescentOptimizer(learning_rate=1e-6)
    train_op = optim.minimize(loss)

with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    batch_size= 32
    for epoch in range(200):
        order = np.argsort(np.random.random(train_label.shape))
        train_data = train_data[order]
        train_label = train_label[order]
        
        res_train_losses = []
        for i in range(train_label.shape[0] // batch_size):
            start = i * batch_size
            end = (i + 1) * batch_size
            res_train_loss, _ = sess.run([loss, train_op],
                     feed_dict={inputs: train_data[start: end],
                                labels: train_label[start: end]})
            res_train_losses.append(res_train_loss)
        res_val_loss = sess.run(loss,
                 feed_dict={inputs: test_data,
                            labels: test_label})
        print('epoch %3d, train loss %2.4f, val loss %2.4f' %
              (epoch, res_train_loss, np.mean(res_train_losses)))
# Out:
# WARNING:tensorflow:From /Users/wangqi/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# epoch   0, train loss 179.5692, val loss 229.8200
# epoch   1, train loss 174.9627, val loss 132.3983
# epoch   2, train loss 125.0651, val loss 121.4357
# epoch   3, train loss 114.7881, val loss 108.7104
# epoch   4, train loss 109.5643, val loss 100.8749
# epoch   5, train loss 126.2539, val loss 99.2776
# epoch   6, train loss 71.9564, val loss 98.1744
# epoch   7, train loss 152.3637, val loss 100.4777
# epoch   8, train loss 90.1115, val loss 96.7439
# epoch   9, train loss 87.3115, val loss 98.6512
# epoch  10, train loss 75.9453, val loss 94.9531
# epoch  11, train loss 82.8367, val loss 94.3665
# epoch  12, train loss 19.6197, val loss 97.5366
# epoch  13, train loss 85.2141, val loss 93.8900
# epoch  14, train loss 103.3013, val loss 98.6369
# epoch  15, train loss 102.9135, val loss 96.5429
# epoch  16, train loss 150.9775, val loss 98.2601
# epoch  17, train loss 103.4763, val loss 90.1044
# epoch  18, train loss 54.5428, val loss 94.4360
# epoch  19, train loss 102.8778, val loss 102.3824
# epoch  20, train loss 98.1748, val loss 92.5802
# epoch  21, train loss 67.0982, val loss 86.1616
# epoch  22, train loss 99.2304, val loss 101.0579
# epoch  23, train loss 114.5857, val loss 93.1322
# epoch  24, train loss 97.2733, val loss 94.3943
# epoch  25, train loss 96.0975, val loss 98.3474
# epoch  26, train loss 99.3215, val loss 86.3394
# epoch  27, train loss 120.0482, val loss 93.1107
# epoch  28, train loss 120.6530, val loss 94.2308
# epoch  29, train loss 119.9475, val loss 91.5761
# epoch  30, train loss 72.9671, val loss 88.1163
# epoch  31, train loss 106.3181, val loss 91.0853
# epoch  32, train loss 59.8208, val loss 93.0947
# epoch  33, train loss 87.6399, val loss 95.4770
# epoch  34, train loss 69.9517, val loss 90.6430
# epoch  35, train loss 63.2232, val loss 91.7171
# epoch  36, train loss 65.5642, val loss 97.9802
# epoch  37, train loss 140.4582, val loss 90.5245
# epoch  38, train loss 99.5118, val loss 93.4822
# epoch  39, train loss 109.9681, val loss 89.8942
# epoch  40, train loss 95.8509, val loss 90.1096
# epoch  41, train loss 83.1801, val loss 90.1370
# epoch  42, train loss 122.7751, val loss 86.5226
# epoch  43, train loss 95.6673, val loss 89.0856
# epoch  44, train loss 95.5971, val loss 93.1594
# epoch  45, train loss 123.9342, val loss 89.9753
# epoch  46, train loss 38.2406, val loss 93.1466
# epoch  47, train loss 81.0796, val loss 92.7890
# epoch  48, train loss 65.9577, val loss 94.0827
# epoch  49, train loss 117.9922, val loss 94.0227
# epoch  50, train loss 100.0875, val loss 85.6408
# epoch  51, train loss 113.9539, val loss 90.5602
# epoch  52, train loss 67.4064, val loss 89.7510
# epoch  53, train loss 76.3297, val loss 91.5030
# epoch  54, train loss 118.2573, val loss 87.2705
# epoch  55, train loss 49.2133, val loss 91.1711
# epoch  56, train loss 119.5746, val loss 92.4998
# epoch  57, train loss 81.2931, val loss 92.0993
# epoch  58, train loss 102.9169, val loss 89.6478
# epoch  59, train loss 71.0695, val loss 89.5592
# epoch  60, train loss 97.2776, val loss 91.1781
# epoch  61, train loss 96.8579, val loss 90.3182
# epoch  62, train loss 86.2546, val loss 97.2820
# epoch  63, train loss 162.7468, val loss 93.7886
# epoch  64, train loss 88.0186, val loss 89.7365
# epoch  65, train loss 85.7001, val loss 98.6432
# epoch  66, train loss 42.5897, val loss 89.1441
# epoch  67, train loss 57.8473, val loss 87.2534
# epoch  68, train loss 125.4368, val loss 91.5933
# epoch  69, train loss 86.4025, val loss 87.7209
# epoch  70, train loss 81.8550, val loss 92.5273
# epoch  71, train loss 105.5185, val loss 90.6085
# epoch  72, train loss 77.8199, val loss 95.4512
# epoch  73, train loss 53.8024, val loss 89.9264
# epoch  74, train loss 63.7323, val loss 90.0512
# epoch  75, train loss 76.2812, val loss 92.5270
# epoch  76, train loss 54.4146, val loss 91.4797
# epoch  77, train loss 80.4686, val loss 94.1851
# epoch  78, train loss 104.3796, val loss 95.9084
# epoch  79, train loss 116.0950, val loss 97.3111
# epoch  80, train loss 92.1466, val loss 91.5915
# epoch  81, train loss 56.0981, val loss 89.7798
# epoch  82, train loss 134.9357, val loss 92.0645
# epoch  83, train loss 44.5300, val loss 88.0800
# epoch  84, train loss 87.5753, val loss 92.0359
# epoch  85, train loss 49.1300, val loss 91.4275
# epoch  86, train loss 47.0811, val loss 91.0262
# epoch  87, train loss 89.2170, val loss 91.2237
# epoch  88, train loss 51.4178, val loss 92.4966
# epoch  89, train loss 65.7158, val loss 91.2964
# epoch  90, train loss 139.8383, val loss 89.8514
# epoch  91, train loss 118.8239, val loss 90.6965
# epoch  92, train loss 84.3071, val loss 93.9156
# epoch  93, train loss 75.8576, val loss 93.2192
# epoch  94, train loss 67.1490, val loss 88.0661
# epoch  95, train loss 116.3085, val loss 94.1651
# epoch  96, train loss 63.7980, val loss 90.6506
# epoch  97, train loss 75.7167, val loss 85.7669
# epoch  98, train loss 142.1751, val loss 96.1859
# epoch  99, train loss 82.9270, val loss 90.3411
# epoch 100, train loss 75.9266, val loss 90.8169
# epoch 101, train loss 126.8735, val loss 94.6942
# epoch 102, train loss 146.7312, val loss 86.0886
# epoch 103, train loss 98.0199, val loss 91.0280
# epoch 104, train loss 121.9020, val loss 90.4965
# epoch 105, train loss 116.5462, val loss 88.8463
# epoch 106, train loss 96.0356, val loss 88.7511
# epoch 107, train loss 97.8416, val loss 87.3515
# epoch 108, train loss 77.7397, val loss 86.5917
# epoch 109, train loss 122.5374, val loss 89.0449
# epoch 110, train loss 103.5844, val loss 88.9325
# epoch 111, train loss 148.3537, val loss 91.0406
# epoch 112, train loss 71.3227, val loss 90.2527
# epoch 113, train loss 134.7964, val loss 91.7723
# epoch 114, train loss 106.9118, val loss 89.5376
# epoch 115, train loss 79.0405, val loss 89.7075
# epoch 116, train loss 89.3147, val loss 90.8598
# epoch 117, train loss 79.1650, val loss 92.2920
# epoch 118, train loss 73.3888, val loss 90.3815
# epoch 119, train loss 101.3136, val loss 90.1305
# epoch 120, train loss 71.3876, val loss 93.4046
# epoch 121, train loss 104.4458, val loss 89.0730
# epoch 122, train loss 108.8385, val loss 90.4629
# epoch 123, train loss 83.1234, val loss 92.2053
# epoch 124, train loss 66.8562, val loss 87.5756
# epoch 125, train loss 69.7218, val loss 92.9905
# epoch 126, train loss 73.6221, val loss 89.3364
# epoch 127, train loss 76.5735, val loss 90.3554
# epoch 128, train loss 76.5960, val loss 90.5284
# epoch 129, train loss 131.9464, val loss 88.5071
# epoch 130, train loss 86.2707, val loss 92.6473
# epoch 131, train loss 36.6382, val loss 89.6182
# epoch 132, train loss 106.9051, val loss 84.6128
# epoch 133, train loss 97.0250, val loss 93.6592
# epoch 134, train loss 112.2224, val loss 87.8899
# epoch 135, train loss 76.8865, val loss 92.2758
# epoch 136, train loss 98.5298, val loss 89.3254
# epoch 137, train loss 79.6257, val loss 91.8529
# epoch 138, train loss 84.6307, val loss 90.4009
# epoch 139, train loss 99.7907, val loss 89.9918
# epoch 140, train loss 68.6718, val loss 92.9878
# epoch 141, train loss 126.1661, val loss 84.5966
# epoch 142, train loss 95.0628, val loss 93.2648
# epoch 143, train loss 122.6608, val loss 94.4068
# epoch 144, train loss 106.9429, val loss 90.7116
# epoch 145, train loss 113.9746, val loss 89.2386
# epoch 146, train loss 97.6001, val loss 90.7229
# epoch 147, train loss 134.6845, val loss 93.3661
# epoch 148, train loss 91.8375, val loss 92.8779
# epoch 149, train loss 61.4636, val loss 86.8418
# epoch 150, train loss 65.9785, val loss 85.9149
# epoch 151, train loss 120.0243, val loss 88.9325
# epoch 152, train loss 64.0345, val loss 90.6419
# epoch 153, train loss 28.7226, val loss 87.6160
# epoch 154, train loss 142.9431, val loss 94.7313
# epoch 155, train loss 73.4739, val loss 89.3730
# epoch 156, train loss 135.4098, val loss 90.5165
# epoch 157, train loss 139.2005, val loss 91.2792
# epoch 158, train loss 66.4591, val loss 88.1196
# epoch 159, train loss 55.3751, val loss 95.0161
# epoch 160, train loss 85.6176, val loss 86.4331
# epoch 161, train loss 64.5773, val loss 94.8245
# epoch 162, train loss 107.0091, val loss 93.4290
# epoch 163, train loss 73.2550, val loss 90.3777
# epoch 164, train loss 93.1508, val loss 95.7132
# epoch 165, train loss 91.9292, val loss 92.0285
# epoch 166, train loss 91.7099, val loss 98.9685
# epoch 167, train loss 93.3100, val loss 87.3175
# epoch 168, train loss 39.0438, val loss 97.2535
# epoch 169, train loss 137.3501, val loss 91.7979
# epoch 170, train loss 53.8264, val loss 89.9850
# epoch 171, train loss 79.8691, val loss 88.4979
# epoch 172, train loss 75.8062, val loss 92.1408
# epoch 173, train loss 75.7898, val loss 89.6134
# epoch 174, train loss 110.2481, val loss 96.5256
# epoch 175, train loss 101.4340, val loss 87.4113
# epoch 176, train loss 54.1954, val loss 87.1115
# epoch 177, train loss 143.7298, val loss 93.1055
# epoch 178, train loss 62.2335, val loss 86.8055
# epoch 179, train loss 96.5057, val loss 91.3237
# epoch 180, train loss 68.5226, val loss 88.0433
# epoch 181, train loss 142.0902, val loss 96.6432
# epoch 182, train loss 115.1230, val loss 92.8643
# epoch 183, train loss 139.7618, val loss 88.1998
# epoch 184, train loss 135.1916, val loss 88.3971
# epoch 185, train loss 71.8799, val loss 92.1150
# epoch 186, train loss 43.2724, val loss 88.1097
# epoch 187, train loss 84.8773, val loss 91.7243
# epoch 188, train loss 83.4047, val loss 90.3835
# epoch 189, train loss 90.7306, val loss 86.7533
# epoch 190, train loss 102.0206, val loss 89.3659
# epoch 191, train loss 105.4169, val loss 89.2746
# epoch 192, train loss 116.5947, val loss 91.6302
# epoch 193, train loss 99.3861, val loss 92.1231
# epoch 194, train loss 118.1514, val loss 92.9901
# epoch 195, train loss 124.9990, val loss 89.6258
# epoch 196, train loss 80.1364, val loss 91.8247
# epoch 197, train loss 68.9182, val loss 96.4414
# epoch 198, train loss 90.4458, val loss 94.2400
# epoch 199, train loss 80.2020, val loss 90.9265

# %% [markdown]
# ## 作业
#
# 1. 复现上述房价预测代码
# 2. 为上述模型训练添加代价变化的`TensorBoard`摘要
# 3. 导入`Fashion_MNIST`数据集并可视化
# 4. 构建全连接神经网络并使用导入的数据训练分类器
# 5. 尝试改进神经网络的结构与训练方法提高模型性能
#
#
# 提示：可使用`tf.keras.datasets.fashion_mnist.load_data()`导入数据
